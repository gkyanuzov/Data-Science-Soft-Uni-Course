# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sqlalchemy

# %%
a = pd.Series([4,5.6, 6], dtype = 'float32')
a.sum()
# Out:
# 15.6

# %%
accidents_data = pd.read_csv("accidents.csv")
accidents_data
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6
# 5         over 20              17

# %%
accidents_data.shape
# Out:
# (6, 2)

# %%
accidents_data.columns
# Out:
# Index(['Miles from Home', '% of Accidents'], dtype='object')

# %%
accidents_data['Miles from Home']
# Out:
# 0    less than 1
# 1         1 to 5
# 2        6 to 10
# 3       11 to 15
# 4       16 to 20
# 5        over 20
# Name: Miles from Home, dtype: object

# %%
type(accidents_data['Miles from Home'])
# Out:
# pandas.core.series.Series

# %%
accidents_data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
plt.barh(accidents_data['Miles from Home'], accidents_data['% of Accidents'])


plt.xlabel('% of Accidents')
plt.show()

# %%
auto_mpg = pd.read_fwf("C:\\Users\\USER\\Desktop\\auto-mpg.data", header= None)
auto_mpg.columns=['mpg', 'cylinders', 'displacement' , 'horsepower', 'weigth', 'acceleration', 'model year', 'origin', 'car_name' ]
auto_mpg.head()
# Out:
#     mpg  cylinders  displacement horsepower  weigth  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                     car_name
# 0       1  "chevrolet chevelle malibu"
# 1       1          "buick skylark 320"
# 2       1         "plymouth satellite"
# 3       1              "amc rebel sst"
# 4       1                "ford torino"

# %%
plt.hist(auto_mpg.mpg, bins = 20)
# Out:
# (array([ 3., 10., 40., 38., 36., 37., 30., 31., 21., 33., 24., 24., 20.,
#         18., 13.,  9.,  4.,  1.,  5.,  1.]),
#  array([ 9.  , 10.88, 12.76, 14.64, 16.52, 18.4 , 20.28, 22.16, 24.04,
#         25.92, 27.8 , 29.68, 31.56, 33.44, 35.32, 37.2 , 39.08, 40.96,
#         42.84, 44.72, 46.6 ]),
#  <a list of 20 Patch objects>)

# %%
auto_mpg.shape
# Out:
# (398, 9)

# %%
auto_mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weigth          float64
# acceleration    float64
# model year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
auto_mpg.horsepower.unique()
auto_mpg[auto_mpg.horsepower == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weigth  acceleration  \
# 32   25.0          4          98.0          ?  2046.0          19.0
# 126  21.0          6         200.0          ?  2875.0          17.0
# 330  40.9          4          85.0          ?  1835.0          17.3
# 336  23.6          4         140.0          ?  2905.0          14.3
# 354  34.5          4         100.0          ?  2320.0          15.8
# 374  23.0          4         151.0          ?  3035.0          20.5
#
#      model year  origin                car_name
# 32           71       1            "ford pinto"
# 126          74       1         "ford maverick"
# 330          80       2  "renault lecar deluxe"
# 336          80       1    "ford mustang cobra"
# 354          81       2           "renault 18i"
# 374          82       1        "amc concord dl"

# %%
auto_mpg.cylinders.min()
# Out:
# 3

# %%
#describes all cols with numbers
auto_mpg.describe()
auto_mpg.describe().T
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# weigth        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model year    398.0    76.010050    3.697627    70.0    73.000    76.0
# origin        398.0     1.572864    0.802055     1.0     1.000     1.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# weigth        3608.000  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0
# origin           2.000     3.0

# %%
green = pd.read_excel('green_tripdata_2015-09.xls')
green.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-01 00:02:34   2015-09-01 00:02:38                  N
# 1         2  2015-09-01 00:04:20   2015-09-01 00:04:24                  N
# 2         2  2015-09-01 00:01:50   2015-09-01 00:04:24                  N
# 3         2  2015-09-01 00:02:36   2015-09-01 00:06:42                  N
# 4         2  2015-09-01 00:00:14   2015-09-01 00:04:20                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           5        -73.979485        40.684956         -73.979431
# 1           5        -74.010796        40.912216         -74.010780
# 2           1        -73.921410        40.766708         -73.914413
# 3           1        -73.921387        40.766678         -73.931427
# 4           1        -73.955482        40.714046         -73.944412
#
#    Dropoff_latitude  Passenger_count  ...  Fare_amount  Extra  MTA_tax  \
# ...

# %%
green.shape
# Out:
# (65535, 21)

# %%
green.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# Lpep_dropoff_datetime    datetime64[ns]
# Store_and_fwd_flag               object
# RateCodeID                        int64
# Pickup_longitude                float64
# Pickup_latitude                 float64
# Dropoff_longitude               float64
# Dropoff_latitude                float64
# Passenger_count                   int64
# Trip_distance                   float64
# Fare_amount                     float64
# Extra                           float64
# MTA_tax                         float64
# Tip_amount                      float64
# Tolls_amount                    float64
# Ehail_fee                       float64
# improvement_surcharge           float64
# Total_amount                    float64
# Payment_type                      int64
# Trip_type                         int64
# dtype: object

# %%
green_filtered = green[(green.Pickup_latitude != 0) & (green.Pickup_longitude != 0)]

# %%
plt.scatter(green_filtered.Pickup_latitude, green_filtered.Pickup_longitude)

# %%
plt.hist(green.Total_amount)
plt.show()

# %%
green[green.Total_amount < 0]
# Out:
#        VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 196           2  2015-09-01 00:11:22   2015-09-01 00:20:26                  N
# 437           2  2015-09-01 00:31:49   2015-09-01 00:35:08                  N
# 568           2  2015-09-01 00:43:31   2015-09-01 00:44:41                  N
# 961           2  2015-09-01 00:14:55   2015-09-01 00:15:11                  N
# 1297          2  2015-09-01 01:00:16   2015-09-01 01:01:07                  N
# ...         ...                  ...                   ...                ...
# 62113         2  2015-09-02 15:12:08   2015-09-02 15:12:12                  N
# 62252         2  2015-09-02 15:04:03   2015-09-02 15:04:39                  N
# 62432         2  2015-09-02 15:25:44   2015-09-02 15:31:13                  N
# 64197         2  2015-09-02 16:03:36   2015-09-02 16:04:12                  N
# 64646         2  2015-09-02 16:09:30   2015-09-02 16:12:43                  N
#
# ...

# %%
green.describe().T
# Out:
#                          count       mean        std         min        25%  \
# VendorID               65535.0   1.784497   0.411174    1.000000   2.000000
# RateCodeID             65535.0   1.124910   0.781101    1.000000   1.000000
# Pickup_longitude       65535.0 -73.808157   3.040510  -75.056404 -73.958015
# Pickup_latitude        65535.0  40.685263   1.676843    0.000000  40.700670
# Dropoff_longitude      65535.0 -73.851127   2.466746  -75.081306 -73.967205
# Dropoff_latitude       65535.0  40.706524   1.360617    0.000000  40.704659
# Passenger_count        65535.0   1.349432   1.023215    0.000000   1.000000
# Trip_distance          65535.0   2.901488   3.026139    0.000000   1.020000
# Fare_amount            65535.0  12.403890  10.604922 -400.000000   6.000000
# Extra                  65535.0   0.304768   0.388277   -1.000000   0.000000
# MTA_tax                65535.0   0.483268   0.094028   -0.500000   0.500000
# ...

# %%
#read from json
books = pd.read_json("https://openlibrary.org/api/books?bibkeys=ISBN:9780345354907,ISBN:0881847690,LCCN:2005041555,ISBN:0060957905&format=json", 
                    orient = 'index')
books
#promenlivite sa v koloni
# Out:
#                                bib_key  \
# ISBN:9780345354907  ISBN:9780345354907
# ISBN:0881847690        ISBN:0881847690
# LCCN:2005041555        LCCN:2005041555
# ISBN:0060957905        ISBN:0060957905
#
#                                                              info_url  \
# ISBN:9780345354907  https://openlibrary.org/books/OL9831606M/The_C...
# ISBN:0881847690     https://openlibrary.org/books/OL22232644M/Watc...
# LCCN:2005041555     https://openlibrary.org/books/OL3421202M/At_th...
# ISBN:0060957905     https://openlibrary.org/books/OL6784868M/Tales...
#
#                        preview  \
# ISBN:9780345354907      borrow
# ISBN:0881847690         borrow
# LCCN:2005041555     restricted
# ISBN:0060957905         noview
#
#                                                           preview_url  \
# ISBN:9780345354907  https://archive.org/details/caseofcharlesdex00...
# ISBN:0881847690     https://archive.org/details/watchersoutoftim00...
# ...

# %%
#reading from sql
engine = sqlalchemy.create_engine("...")

# %%
pd.read_sql('select * from sales', engine)

# %%
#web scraping
